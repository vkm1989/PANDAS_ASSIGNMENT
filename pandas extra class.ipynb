# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('raw-data.csv')
df.head()
# Out:
#       id Employee Full Name         DOB                         email  gender  \
# 0  201.0        Salim Pound  02-12-2018           spound0@spotify.com    Male
# 1  202.0     Madelene Lutas   9/20/2018                mlutas1@si.edu  Female
# 2  203.0   Dolli Swanbourne  11/18/2018  dswanbourne2@istockphoto.com  Female
# 3  204.0    Graeme Croisier   9/29/2018     graeme.croisire@gmail.com    Male
# 4  205.0     Jillana Physic   4/19/2018       jphysic4@yellowbook.com  Female
#
#      Company Country      Income.1  Income.2  Total_income
# 0     Google   India  46476.638081     529.0       47006.0
# 1     Amazon     USA  54174.687948     720.0       54895.0
# 2      Intel     USA  43467.240728     234.0       43702.0
# 3  Accenture  Canada  46784.630879     657.0       47442.0
# 4  Accenture   India  57486.495560    1947.0       59434.0

# %% [markdown]
# Q1. Bring DOB in the same format

# %%
df.dtypes
# Out:
# id                    float64
# Employee Full Name     object
# DOB                    object
# email                  object
# gender                 object
# Company                object
# Country                object
# Income.1              float64
# Income.2              float64
# Total_income          float64
# dtype: object

# %%
df.head()
# Out:
#       id Employee Full Name         DOB                         email  gender  \
# 0  201.0        Salim Pound  02-12-2018           spound0@spotify.com    Male
# 1  202.0     Madelene Lutas   9/20/2018                mlutas1@si.edu  Female
# 2  203.0   Dolli Swanbourne  11/18/2018  dswanbourne2@istockphoto.com  Female
# 3  204.0    Graeme Croisier   9/29/2018     graeme.croisire@gmail.com    Male
# 4  205.0     Jillana Physic   4/19/2018       jphysic4@yellowbook.com  Female
#
#      Company Country      Income.1  Income.2  Total_income
# 0     Google   India  46476.638081     529.0       47006.0
# 1     Amazon     USA  54174.687948     720.0       54895.0
# 2      Intel     USA  43467.240728     234.0       43702.0
# 3  Accenture  Canada  46784.630879     657.0       47442.0
# 4  Accenture   India  57486.495560    1947.0       59434.0

# %%
# convert DOB in date time format

df['DOB'] = pd.to_datetime(df['DOB'])
df
# Out:
#        id   Employee Full Name        DOB                          email  \
# 0   201.0          Salim Pound 2018-02-12            spound0@spotify.com
# 1   202.0       Madelene Lutas 2018-09-20                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne 2018-11-18   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier 2018-09-29      graeme.croisire@gmail.com
# 4   205.0       Jillana Physic 2018-04-19        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman 2018-04-26        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson 2018-03-28    modesta.batterson@gmail.com
# 7   208.0          Melina Boon 2017-12-18               mboon7@weibo.com
# 8   209.0            Nomi Warn 2018-01-16               nwarn8@sogou.com
# 9   210.0             jimcarry 1970-01-01            jim.carry@gmail.com
# 10  211.0       Charleen Auden 2018-04-15                caudena@nba.com
# 11  212.0          Dame Povele 2018-06-26         dpoveleb@bloglovin.com
# ...

# %%
df[]

# %%
df.columns
# Out:
# Index(['id', 'Employee Full Name', 'DOB', 'email', 'gender', 'Company',
#        'Country', 'Income.1', 'Income.2', 'Total_income'],
#       dtype='object')

# %%
df[['First','Last']] = df['Employee Full Name'].str.split("_",expand=True)
   
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df[['First','Last']] = df['Employee Full Name'].str.split("_",expand=True)
#       3 df
#
# File C:\anaconda\lib\site-packages\pandas\core\frame.py:3968, in DataFrame.__setitem__(self, key, value)
#    3966     self._setitem_frame(key, value)
#    3967 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3968     self._setitem_array(key, value)
#    3969 elif isinstance(value, DataFrame):
#    3970     self._set_item_frame_value(key, value)
#
# File C:\anaconda\lib\site-packages\pandas\core\frame.py:4010, in DataFrame._setitem_array(self, key, value)
#    4005 else:
#    4006     # Note: unlike self.iloc[:, indexer] = value, this will
#    4007     #  never try to overwrite values inplace
#    4009     if isinstance(value, DataFrame):
# ...

# %%
df[['First','Last']] = dfEmployee Full Name.apply(lambda x: pd.Series(str(x).split("_")))
# Out:
#   Cell In[12], line 1
#     df[['First','Last']] = df.Employee Full Name.apply(lambda x: pd.Series(str(x).split("_")))
#                                        ^
# SyntaxError: invalid syntax
